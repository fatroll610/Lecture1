# %% [markdown]
# STEP1: IMPORT PACKAGES

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# STEP2: CONNECT TO GOOGLE DRIVE

# %%
drive.mount('/content/gdrive/',force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# STEP3: READ DATA

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Lecture1/cpi.csv")
df
# Out:
#             Date    Index  Inflation
# 0     1913-01-01    9.800        NaN
# 1     1913-02-01    9.800       0.00
# 2     1913-03-01    9.800       0.00
# 3     1913-04-01    9.800       0.00
# 4     1913-05-01    9.700      -1.02
# ...          ...      ...        ...
# 1208  2013-09-01  234.149       0.12
# 1209  2013-10-01  233.546      -0.26
# 1210  2013-11-01  233.069      -0.20
# 1211  2013-12-01  233.049      -0.01
# 1212  2014-01-01  233.916       0.37
#
# [1213 rows x 3 columns]

# %% [markdown]
# STEP4: DATA CLEANING AND VIZ

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (25,5))
plt.plot(df["Inflation"])
plt.title("Inflation from 1913 to 2014")
plt.xlabel("Date")
plt.ylabel("Inflation")
plt.grid()
plt.show()

# %% [markdown]
# We can see there are some dramatic change during some time period, other time is pretty smooth.
